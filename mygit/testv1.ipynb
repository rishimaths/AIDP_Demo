# %%
import mlflow
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType
print("Tracking URI:", mlflow.get_tracking_uri())
print("Experiment name:", EXPERIMENT_NAME)
print("Found:", mlflow.get_experiment_by_name(EXPERIMENT_NAME))
# Out:
# Tracking URI: DEFAULT_HUB_PROXY_ENDPOINT/20240831/dataLakes/DEFAULT_HUB_ID/workspaces/DEFAULT_WS_KEY/mlops/
# opc-request-id: csid241b89854cdba5a8066254e7d11c/e5311bdb767245d39c6109057fcae0ee/9CCFCE04473C4FD98159C00C2C1F20C8
#
# Command ID 8a20d83e-f104-440a-8c68-c3d61dc2f80b failed with java.lang.RuntimeException: [Command 8a20d83e-f104-440a-8c68-c3d61dc2f80b in Context 6250b72e-68a1-4af1-bdc3-67b438e202c5] failed with error:
#  ---------------------------------------------------------------------------NameError                                 Traceback (most recent call last)File /tmp/ipykernel_61341/3763834351.py:5
#       3 from mlflow.entities import ViewType
#       4 print("Tracking URI:", mlflow.get_tracking_uri())
# ----> 5 print("Experiment name:", EXPERIMENT_NAME)
#       6 print("Found:", mlflow.get_experiment_by_name(EXPERIMENT_NAME))
# NameError: name 'EXPERIMENT_NAME' is not defined
